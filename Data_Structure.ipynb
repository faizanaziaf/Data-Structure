# %% [markdown]
# **Q1:** What are data structures, and why are they important?
# **A1:** Data structures are ways to organize and store data efficiently; they are crucial for optimizing data access, manipulation, and processing.
#
# **Q2:** Explain the difference between mutable and immutable data types with examples.
# **A2:** Mutable data types (e.g., lists) can be changed after creation, while immutable types (e.g., tuples) cannot.
#
# **Q3:** What are the main differences between lists and tuples in Python?
# **A3:** Lists are mutable, while tuples are immutable; lists use more memory but are more flexible.
#
# **Q4:** Describe how dictionaries store data.
# **A4:** Dictionaries store data as key-value pairs using a hash map for fast lookups.
#
# **Q5:** Why might you use a set instead of a list in Python?
# **A5:** Sets are useful for eliminating duplicates and performing fast membership checks.
#
# **Q6:** What is a string in Python, and how is it different from a list?
# **A6:** A string is an immutable sequence of characters, while a list is mutable and can hold various data types.
#
# **Q7:** How do tuples ensure data integrity in Python?
# **A7:** Tuples are immutable, preventing accidental changes and ensuring consistency.
#
# **Q8:** What is a hash table, and how does it relate to dictionaries in Python?
# **A8:** A hash table is a data structure for fast lookups; dictionaries in Python use hash tables to store key-value pairs.
#
# **Q9:** Can lists contain different data types in Python?
# **A9:** Yes, lists can contain elements of different data types.
#
# **Q10:** Explain why strings are immutable in Python.
# **A10:** Strings are immutable to ensure security, data integrity, and efficiency in memory usage.
#
# **Q11:** What advantages do dictionaries offer over lists for certain tasks?
# **A11:** Dictionaries offer faster lookups by keys and are ideal for associative data.
#
# **Q12:** Describe a scenario where using a tuple would be preferable over a list.
# **A12:** Use a tuple when data should not change, like representing fixed coordinates or settings.
#
# **Q13:** How do sets handle duplicate values in Python?
# **A13:** Sets automatically remove duplicate values, ensuring all elements are unique.
#
# **Q14:** How does the “in” keyword work differently for lists and dictionaries?
# **A14:** For lists, `in` checks for values; for dictionaries, it checks for keys.
#
# **Q15:** Can you modify the elements of a tuple? Explain why or why not.
# **A15:** No, tuples are immutable, meaning their elements cannot be changed.
#
# **Q16:** What is a nested dictionary, and give an example of its use case.
# **A16:** A nested dictionary has dictionaries within dictionaries, e.g., storing student info with subjects as keys.
#
# **Q17:** Describe the time complexity of accessing elements in a dictionary.
# **A17:** Accessing elements in a dictionary has an average time complexity of O(1).
#
# **Q18:** In what situations are lists preferred over dictionaries?
# **A18:** Use lists when maintaining order or sequential access is important.
#
# **Q19:** Why are dictionaries considered unordered, and how does that affect data retrieval?
# **A19:** Dictionaries are unordered because they store data based on keys, not positions; retrieval relies on keys, not order.
#
# **Q20:** Explain the difference between a list and a dictionary in terms of data retrieval.
# **A20:** Lists retrieve data by index, while dictionaries retrieve data by keys.

# %%
# 1. Write a code to create a string with your name and print it.
name = "Your Name"
print(name)

# 2. Write a code to find the length of the string "Hello World".
string = "Hello World"
print(len(string))

# 3. Write a code to slice the first 3 characters from the string "Python Programming".
string = "Python Programming"
print(string[:3])

# 4. Write a code to convert the string "hello" to uppercase.
string = "hello"
print(string.upper())

# 5. Write a code to replace the word "apple" with "orange" in the string "I like apple".
string = "I like apple"
new_string = string.replace("apple", "orange")
print(new_string)

# 6. Write a code to create a list with numbers 1 to 5 and print it.
numbers = [1, 2, 3, 4, 5]
print(numbers)

# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].
numbers = [1, 2, 3, 4]
numbers.append(10)
print(numbers)

# 8. Write a code to remove the number 3 from the list [1, 2, 3, 4, 5].
numbers = [1, 2, 3, 4, 5]
numbers.remove(3)
print(numbers)

# 9. Write a code to access the second element in the list ['a', 'b', 'c', 'd'].
letters = ['a', 'b', 'c', 'd']
print(letters[1])

# 10. Write a code to reverse the list [10, 20, 30, 40, 50].
numbers = [10, 20, 30, 40, 50]
numbers.reverse()
print(numbers)

# 11. Write a code to create a tuple with the elements 10, 20, 30 and print it.
my_tuple = (10, 20, 30)
print(my_tuple)

# 12. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
fruits = ('apple', 'banana', 'cherry')
print(fruits[0])

# 13. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
numbers = (1, 2, 3, 2, 4, 2)
print(numbers.count(2))

# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
animals = ('dog', 'cat', 'rabbit')
print(animals.index('cat'))

# 15. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
fruits = ('apple', 'orange', 'banana')
print('banana' in fruits)

# 16. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
my_set = {1, 2, 3, 4, 5}
print(my_set)

# 17. Write a code to add the element 6 to the set {1, 2, 3, 4}.
my_set = {1, 2, 3, 4}
my_set.add(6)
print(my_set)

# 18. Write a code to create a tuple with the elements 10, 20, 30 and print it.
my_tuple = (10, 20, 30)
print(my_tuple)

# 19. Write a code to access the first element of the tuple ('apple', 'banana', 'cherry').
fruits = ('apple', 'banana', 'cherry')
print(fruits[0])

# 20. Write a code to count how many times the number 2 appears in the tuple (1, 2, 3, 2, 4, 2).
numbers = (1, 2, 3, 2, 4, 2)
print(numbers.count(2))

# 21. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').
animals = ('dog', 'cat', 'rabbit')
print(animals.index('cat'))

# 22. Write a code to check if the element "banana" is in the tuple ('apple', 'orange', 'banana').
fruits = ('apple', 'orange', 'banana')
print('banana' in fruits)

# 23. Write a code to create a set with the elements 1, 2, 3, 4, 5 and print it.
my_set = {1, 2, 3, 4, 5}
print(my_set)

# 24. Write a code to add the element 6 to the set {1, 2, 3, 4}.
my_set = {1, 2, 3, 4}
my_set.add(6)
print(my_set)
# Out:
# Your Name
# 11
# Pyt
# HELLO
# I like orange
# [1, 2, 3, 4, 5]
# [1, 2, 3, 4, 10]
# [1, 2, 4, 5]
# b
# [50, 40, 30, 20, 10]
# (10, 20, 30)
# apple
# 3
# 1
# True
# {1, 2, 3, 4, 5}
# {1, 2, 3, 4, 6}
# (10, 20, 30)
# apple
# 3
# 1
# True
# {1, 2, 3, 4, 5}
# {1, 2, 3, 4, 6}
